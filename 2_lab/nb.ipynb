# %% [markdown]
# # Як проявляє себе ООП в Пайтоні
# > програми можуть писатись як набір команд, які потрібно виконати для отримання результату
# > або ми можемо використати команди мови програмування для опису певного фізичного явища
# > у базовому представленні, числа є також абстракцією, наприклад ми можемо користуватись арабськими або римськими цифрами, однак астракція полягає у тому, що цифри це є відображення к-сть чогось
# > У Пайтоні, цифри також представлені абстракцією яка вказує на тип даних, або яке це число

# %%
a = 1
print(f"Змінна а має значеня {a}")
b = int(1)
print(f"Змінна b має значеня {b}")
# Out:
# Змінна а має значеня 1
# Змінна b має значеня 1

# %% [markdown]
# Це ми розуміємо арабську цифру 1, а щоб її зрозумів комп'ютер ми повинні використати абстрацію, яка є типом даних, в даному випадку `int`

# %%
print(f"Змінна самого числа буде мати тип: {type(a)}, а змінна заданого типом int буде мати тип: {type(b)}")
# Out:
# Змінна самого числа буде мати тип: <class 'int'>, а змінна заданого типом int буде мати тип: <class 'int'>

# %% [markdown]
# Всетаки абстракції можна виражати по різному, і ми можемо задати число, як число, або як символ

# %%
c = '1'
print(f"Власне як число будемо мати {type(a)} та значення {a}, а як символ будемо мати {type(c)} та значення {c}")
# Out:
# Власне як число будемо мати <class 'int'> та значення 1, а як символ будемо мати <class 'str'> та значення 1

# %% [markdown]
# Маючи абстракції, що таке число та, що таке символ, ми можемо тепер з ним працювати

# %%
d = a + b
e = c + str(a)
print(f"Працюючи з абстракцією чисел додавання двох чисел буде мати результат {type(d)} = {d}")
print(f"Працюючи з абстракцією символів додавання двох символів буде мати результат {type(e)} = {e}")
# Out:
# Працюючи з абстракцією чисел додавання двох чисел буде мати результат <class 'int'> = 2
# Працюючи з абстракцією символів додавання двох символів буде мати результат <class 'str'> = 11

# %%
p = print("Вивід від прінту")
print(f"Тип нашого прінту буде: {type(print)}\nЙого виклик буде мати значення: {type(p)}\nА йго значення буде: {p} ")
# Out:
# Вивід від прінту
# Тип нашого прінту буде: <class 'builtin_function_or_method'>
# Його виклик буде мати значення: <class 'NoneType'>
# А йго значення буде: None

# %% [markdown]
# Будь-що у Пайтон описується абстракціями, і вони співвідносяться з парою `клас` і `об'єкт`
# Клас - це загальне уявлення про абстракції, її опис, як сама абстракція повинна бути представлена, з якими характеристиками та які властивості повинна мати. Для прикладу, у грі є персонажі, ці персонажі можуть мати певний клас, можуть мати набір скілів, можуть мати вигляд та певні ійтеми. Все що може з себе представляти персонаж це є КЛАС, тому що клас описує що таке персонаж в грі. Клас це абстракція, яка описує цифрового аватара у грі.
# Об'єкт - це конкретне вираження одного унікального представлення класу, або як в книжках пишуть - екземпляр класу. Для пояснення з грою, ваш ігровоий персонаж є об'єктом класу Персонаж і має конкретний клас/расу Воїн/Ульф, має конкретний набір скілів, вигляд та якісь ітеми.
#
# Приклад: в грі є ітеми, наприклад мечі. Меч це є абстракція, тому він є класом 'МЕЧ'. Ви вибили певний ітем меча, `короткий меч` який має вигляд катани, з ручкою синього кольору, якість зелена(продвинута) та має характеристику атаки +15 і додає силу + 2, тому цей меч є об'єктом класу `МЕЧ`

# %% [markdown]
# Поки ми дивились лише на вбудовані класи та об'єкти, які програмісти створювали до нас. Однак ми також можемо описувати певні явища і створювати класи та об'єкти. Далі давайте створимо власне наш перший клас.

# %% [markdown]
# Ще клас можна уявити собі, як шаблон, а відповідно об'єкт це конкретна "річ" зроблена по шаблону.
# Ми спробуємо описати у програмі: мечі та процес отримання конкретного меча - гравцем.

# %%
swords_name = ["Короткий меч", "Довгий меч", "Катана", "Рапіра"]
swords_rarity = ["Green", "Blue", "Exotic", "Epic"]
swords_damag = [2, 5, 4, 5]
swords_vitality = [10, 10, 15, 20]

from random import randint
print(f"Моделюємо випадання якогось числа, що буде вказувати на меч")
i = randint(0, len(swords_name) -1)
print(f"Вітаємо, Вам випав меч!\nСтатистика:\nНазва: {swords_name[i]}!\nРідкість: {swords_rarity[i]}.\nДамаг: + {swords_damag[i]}\nВитривалість: + {swords_vitality[i]}")
# Out:
# Моделюємо випадання якогось числа, що буде вказувати на меч
# Вітаємо, Вам випав меч!
# Статистика:
# Назва: Довгий меч!
# Рідкість: Blue.
# Дамаг: + 5
# Витривалість: + 10

# %% [markdown]
# Давайте спробуємо зробити такий самий меч, тільки за допомогою ООП у найпростіший спосіб з використаннями динамічних атрибутів.

# %%
class Swords:
    pass
# створюємо 1 об'єкт класу Мечі
s1 = Swords()
# Динамічно задаємо атрибути
s1.name = "Короткий меч"
s1.rarity = "Green"
s1.damage = 2
s1.vitality = 10
s1.bonus = "Немає"

s2 = Swords()
s2.name = "Довгий меч"
s2.rarity = "Blue"
s2.damage = 5
s2.vitality = 10
s2.bonus = "Спритність"

s3 = Swords()
s3.name = "Катана"
s3.rarity = "Exotic"
s3.damage = 3
s3.vitality = 15
s3.bonus = "Берсерк"

s4 = Swords()
s4.name = "Рапіра"
s4.rarity = "Epic"
s4.damage = 5
s4.vitality = 20
s4.bonus = "Швидкі удари"

swords = [s1, s2, s3, s4]
i = randint(0, len(swords) -1)
s = swords[i]
print(f"Вітаємо, Вам випав меч!\nСтатистика:\nНазва: {s.name}!\nРідкість: {s.rarity}.\nДамаг: + {s.damage}\nВитривалість: + {s.vitality}\nБонус: {s.bonus}")
# Out:
# Вітаємо, Вам випав меч!
# Статистика:
# Назва: Довгий меч!
# Рідкість: Blue.
# Дамаг: + 5
# Витривалість: + 10
# Бонус: Спритність
